# %% [markdown]
# <a href="https://colab.research.google.com/github/nicoleariasl/AnDatos/blob/main/LaboratorioMapa_NicoleArias.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import folium

# %%
from folium.plugins import MiniMap

# %%
Heredia = folium.Map(location = (56.65883, -115.16678))
Heredia

#10.094108, 99.827673

# %%
from branca.element import Figure

popuptext = '<b>Sairee Beach</b>'
my_map = folium.Map(location = [10.2856822, -84.9008912],zoom_start = 16,titles='stamenterrain')


folium.Marker(location = [10.2856822, -84.9008912], popup=popuptext,icon=folium.Icon(color="orange",icon="ok-sign")).add_to(my_map)

folium.Circle(location = [10.2856822, -84.9008912], color= "purple",weight = 6, fill_color="red",fill_opacity=0.5,tooltip="Sairee Beach").add_to(my_map)


minimap = MiniMap(title_layer = 'stamenterrain',position = 'bottomright')

my_map.add_child(minimap)
my_map.save('C:folium.html')

my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
from branca.element import Figure

popuptext = '<b>Sairee Beach</b>'
my_map = folium.Map(location = [10.094182, 99.827648],zoom_start = 16,titles='stamenterrain')


folium.Marker(location = [10.094182, 99.827648], popup=popuptext,icon=folium.Icon(color="orange",icon="ok-sign")).add_to(my_map)

folium.Circle(location = [10.094182, 99.827648], color= "purple",weight = 6, fill_color="red",fill_opacity=0.5,tooltip="Sairee Beach").add_to(my_map)


minimap = MiniMap(title_layer = 'stamenterrain',position = 'bottomright')

my_map.add_child(minimap)
my_map.save('C:folium.html')

#my_map

# %%
from branca.element import Figure

popuptext = '<b>Sairee Beach</b>'
my_map = folium.Map(location = [9.969740, -84.129009],zoom_start = 16,titles='stamenterrain')


folium.Marker(location = [9.969740, -84.129009], popup=popuptext,icon=folium.Icon(color="orange",icon="ok-sign")).add_to(my_map)

folium.Circle(location = [9.969740, -84.129009], color= "purple",weight = 6, fill_color="red",fill_opacity=0.5,tooltip="Sairee Beach").add_to(my_map)


minimap = MiniMap(title_layer = 'stamenterrain',position = 'bottomright')

my_map.add_child(minimap)
my_map.save('C:folium.html')

my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
fig = Figure(width=1000, height=500)
fig.add_child(my_map)
fig
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...
